# %%
# %pip install roboflow
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.50-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in c:\users\meeka\desktop\football-analysis\.venv\lib\site-packages (from roboflow) (2024.12.14)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in c:\users\meeka\desktop\football-analysis\.venv\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\meeka\desktop\football-analysis\.venv\lib\site-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in c:\users\meeka\desktop\football-analysis\.venv\lib\site-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\meeka\desktop\football-analysis\.venv\lib\site-packages (from roboflow) (2.2.1)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\meeka\desktop\football-analysis\.venv\lib\site-packages (from roboflow) (11.0.0)
# Requirement already satisfied: python-dateutil in c:\users\meeka\desktop\football-analysis\.venv\lib\site-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests in c:\users\meeka\desktop\football-analysis\.venv\lib\site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in c:\users\meeka\desktop\football-analysis\.venv\lib\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\meeka\desktop\football-analysis\.venv\lib\site-packages (from roboflow) (2.3.0)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\meeka\desktop\football-analysis\.venv\lib\site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\meeka\desktop\football-analysis\.venv\lib\site-packages (from roboflow) (6.0.2)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: colorama in c:\users\meeka\desktop\football-analysis\.venv\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\meeka\desktop\football-analysis\.venv\lib\site-packages (from matplotlib->roboflow) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\meeka\desktop\football-analysis\.venv\lib\site-packages (from matplotlib->roboflow) (4.55.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\meeka\desktop\football-analysis\.venv\lib\site-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\meeka\desktop\football-analysis\.venv\lib\site-packages (from matplotlib->roboflow) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\meeka\desktop\football-analysis\.venv\lib\site-packages (from requests->roboflow) (3.4.1)
# Downloading roboflow-1.1.50-py3-none-any.whl (81 kB)
# Downloading idna-3.7-py3-none-any.whl (66 kB)
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    - -------------------------------------- 1.0/38.8 MB 8.4 MB/s eta 0:00:05
#    -- ------------------------------------- 2.6/38.8 MB 6.6 MB/s eta 0:00:06
#    ---- ----------------------------------- 4.2/38.8 MB 6.6 MB/s eta 0:00:06
#    ----- ---------------------------------- 5.8/38.8 MB 6.8 MB/s eta 0:00:05
#    ------- -------------------------------- 6.8/38.8 MB 6.6 MB/s eta 0:00:05
#    -------- ------------------------------- 8.1/38.8 MB 6.4 MB/s eta 0:00:05
#    --------- ------------------------------ 9.2/38.8 MB 6.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 10.7/38.8 MB 6.3 MB/s eta 0:00:05
#    ------------ --------------------------- 12.1/38.8 MB 6.4 MB/s eta 0:00:05
#    ------------- -------------------------- 13.4/38.8 MB 6.4 MB/s eta 0:00:04
#    --------------- ------------------------ 14.7/38.8 MB 6.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 16.0/38.8 MB 6.3 MB/s eta 0:00:04
#    ------------------ --------------------- 17.8/38.8 MB 6.4 MB/s eta 0:00:04
#    ------------------- -------------------- 19.1/38.8 MB 6.5 MB/s eta 0:00:04
#    --------------------- ------------------ 20.4/38.8 MB 6.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 22.3/38.8 MB 6.6 MB/s eta 0:00:03
#    ------------------------ --------------- 23.9/38.8 MB 6.7 MB/s eta 0:00:03
#    -------------------------- ------------- 25.7/38.8 MB 6.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 27.5/38.8 MB 6.8 MB/s eta 0:00:02
#    ------------------------------ --------- 29.4/38.8 MB 7.0 MB/s eta 0:00:02
#    ------------------------------- -------- 30.9/38.8 MB 7.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.0/38.8 MB 7.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.6/38.8 MB 7.2 MB/s eta 0:00:01
#    ------------------------------------- -- 36.4/38.8 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.8 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 7.2 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: filetype, python-dotenv, opencv-python-headless, idna, requests-toolbelt, roboflow
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 python-dotenv-1.0.1 requests-toolbelt-1.0.0 roboflow-1.1.50
# Note: you may need to restart the kernel to use updated packages.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="CkKfnDOjQYfPSD7CTpfn")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
